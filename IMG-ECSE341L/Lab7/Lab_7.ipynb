# %% [markdown]
# <a href="https://colab.research.google.com/github/adityav1810/Semester_5_Labs/blob/master/ECSE341L-ImageProcessing/Lab7/Lab_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
print('Original Image')
cv2_imshow(im)
im=cv2.imread('/content/parrot.png')
max_val=np.max(im)
print('Subtracted max val from each image pixel')
cv2_imshow(max_val-im)
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=486x362 at 0x7F45355845F8>
# Subtracted max val from each image pixel
# <PIL.Image.Image image mode=RGB size=486x362 at 0x7F4535584668>

# %%
img_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
img_gray.shape
print('Original GrayScale Image')
cv2_imshow(img_gray)
c = 255 / np.log(1 + np.max(img_gray)) 
log_image = c * (np.log(img_gray + 1)) 
log_image = np.array(log_image, dtype = np.uint8) 
print('Applied Log Transformation on GrayScale Image')
cv2_imshow(log_image)
# Out:
# Original GrayScale Image
# <PIL.Image.Image image mode=L size=486x362 at 0x7F4531B0CA90>
# Applied Log Transformation on GrayScale Image
# <PIL.Image.Image image mode=L size=486x362 at 0x7F4531B0CA20>
